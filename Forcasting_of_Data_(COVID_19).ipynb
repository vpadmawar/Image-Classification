# %% [markdown]
# <a href="https://colab.research.google.com/github/vpadmawar/Image-Classification/blob/main/Forcasting_of_Data_(COVID_19).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libararies and dataset

import pandas as pd
df = pd.read_csv('owid-covid-data.csv')
df
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 0          AFG      Asia  ...           64.83                   0.511
# 1          AFG      Asia  ...           64.83                   0.511
# 2          AFG      Asia  ...           64.83                   0.511
# 3          AFG      Asia  ...           64.83                   0.511
# 4          AFG      Asia  ...           64.83                   0.511
# ...        ...       ...  ...             ...                     ...
# 76409      ZWE    Africa  ...           61.49                   0.571
# 76410      ZWE    Africa  ...           61.49                   0.571
# 76411      ZWE    Africa  ...           61.49                   0.571
# 76412      ZWE    Africa  ...           61.49                   0.571
# 76413      ZWE    Africa  ...           61.49                   0.571
#
# [76414 rows x 59 columns]

# %%
# Considering location india for forcasting 

df_ind=df[df.location=="India"]
df_ind
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 31361      IND      Asia  ...           69.66                   0.645
# 31362      IND      Asia  ...           69.66                   0.645
# 31363      IND      Asia  ...           69.66                   0.645
# 31364      IND      Asia  ...           69.66                   0.645
# 31365      IND      Asia  ...           69.66                   0.645
# ...        ...       ...  ...             ...                     ...
# 31773      IND      Asia  ...           69.66                   0.645
# 31774      IND      Asia  ...           69.66                   0.645
# 31775      IND      Asia  ...           69.66                   0.645
# 31776      IND      Asia  ...           69.66                   0.645
# 31777      IND      Asia  ...           69.66                   0.645
#
# [417 rows x 59 columns]

# %%
df_ind

df_new=pd.DataFrame(data=[list(df_ind.date),list(df_ind.new_deaths)])
df_new=df_new.transpose()

# %%
df_new.head()
# Out:
#             0    1
# 0  2020-01-30  NaN
# 1  2020-01-31  NaN
# 2  2020-02-01  NaN
# 3  2020-02-02  NaN
# 4  2020-02-03  NaN

# %%
l=[df_new[0][j] for j in range(41)]

# %%
df_new=df_new.dropna()

# %%
df_new.head()
# Out:
#              0  1
# 41  2020-03-11  1
# 42  2020-03-12  0
# 43  2020-03-13  1
# 44  2020-03-14  0
# 45  2020-03-15  0

# %%
df_new.isnull().sum()
# Out:
# 0    0
# 1    0
# dtype: int64

# %%
df_new=df_new.rename(columns={0:'ds',1:'y'})

# %%
df_new['ds']=pd.to_datetime(df_new['ds'])
df_new['y']=df_new['y'].astype(int)
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 376 entries, 41 to 416
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      376 non-null    datetime64[ns]
#  1   y       376 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 8.8 KB

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
plt.plot(df_new['ds'],df_new['y'])
plt.show()

# %%
import fbprophet
op=fbprophet.Prophet()
op.fit(df_new)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# **Forcasting**

# %%
forecast=op.make_future_dataframe(periods=31,freq='D')
forecast=op.predict(forecast)

# %%
op.plot(forecast,xlabel='Date',ylabel='=New_Death_Cases');
